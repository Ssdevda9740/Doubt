# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
mc=pd.read_csv('micro_credit.csv', parse_dates=['pdate'])
mc.head(10)
# Out:
#    Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789   272.0   3055.050000   3065.150000
# 1           2      1  76462I70374   712.0  12122.000000  12124.750000
# 2           3      1  17943I70372   535.0   1398.000000   1398.000000
# 3           4      1  55773I70781   241.0     21.228000     21.228000
# 4           5      1  03813I82730   947.0    150.619333    150.619333
# 5           6      1  35819I70783   568.0   2257.362667   2261.460000
# 6           7      1  96759I84459   545.0   2876.641667   2883.970000
# 7           8      1  09832I90846   768.0  12905.000000  17804.150000
# 8           9      1  59772I84450  1191.0     90.695000     90.695000
# 9          10      1  56331I70783   536.0     29.357333     29.357333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# ...

# %%
mr=mc.drop('Unnamed: 0', axis=1)

# %%
mr
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
# ...

# %%
mr.dtypes
# Out:
# label                            int64
# msisdn                          object
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30              float64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# fr_da_rech90                     int64
# ...

# %% [markdown]
# In this we can clearly see that two columns are in object type and one column pdate is in
# datetime type so we need to convert them into float or int type that is numerical value by using LabelEncoder or onehotencoder.
# we area going to use label encoder as it converts more than two variable without any constraints.

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
mr['msisdn']=lb.fit_transform(mr['msisdn'])
mr['pcircle']=lb.fit_transform(mr['pcircle'])
mr['pdate']=lb.fit_transform(mr['pdate'])

# %%
mr.dtypes
# Out:
# label                     int64
# msisdn                    int32
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %%
mr.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
mr.columns.value_counts().sum()
# Out:
# 36

# %%
sns.heatmap(mr.isnull())

# %%
mr.corr()
# Out:
#                          label    msisdn       aon  daily_decr30  \
# label                 1.000000  0.001976 -0.003785      0.168298
# msisdn                0.001976  1.000000  0.000566      0.000717
# aon                  -0.003785  0.000566  1.000000      0.001104
# daily_decr30          0.168298  0.000717  0.001104      1.000000
# daily_decr90          0.166150  0.000950  0.000374      0.977704
# rental30              0.058085 -0.001404 -0.000960      0.442066
# rental90              0.075521 -0.000691 -0.000790      0.458977
# last_rech_date_ma     0.003728 -0.000928  0.001692      0.000487
# last_rech_date_da     0.001711  0.001400 -0.001693     -0.001636
# last_rech_amt_ma      0.131804 -0.002368  0.004256      0.275837
# cnt_ma_rech30         0.237331  0.000617 -0.003148      0.451385
# fr_ma_rech30          0.001330 -0.001804 -0.001163     -0.000577
# sumamnt_ma_rech30     0.202828  0.001094  0.000707      0.636536
# ...

# %%
mr.describe()
# Out:
#                label         msisdn            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177   93100.650179    8112.343445    5381.402289
# std         0.330519   53758.461427   75696.082531    9220.623400
# min         0.000000       0.000000     -48.000000     -93.012667
# 25%         1.000000   46506.000000     246.000000      42.440000
# 50%         1.000000   93073.000000     527.000000    1469.175667
# 75%         1.000000  139626.000000     982.000000    7244.000000
# max         1.000000  186242.000000  999860.755200  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000       209593.00000
# mean     6082.515068    2692.581910    3483.406534         3755.84780
# std     10918.812767    4308.586781    5770.461279        53905.89223
# min       -93.012667  -23737.140000  -24720.580000          -29.00000
# ...

# %%
plt.figure(figsize=(18,16))
sns.heatmap(mr.corr(), annot=True, cmap='Blues')

# %% [markdown]
# we are going to plot some graph related to the columns it would help us understand better realtionship between the columns.
# we are going to use the visualisation commands like seaborn and matplotlib to plot distplot, countplot and catplot and even at
# the end we are going to use boxplot to understand the outliers present in the data.

# %%
sns.countplot(x='label', data=mr)

# %%
sns.countplot(x='medianamnt_loans30', data=mr)

# %%
sns.distplot(mr['rental30'], bins=10)

# %%
sns.distplot(mr['last_rech_amt_ma'])

# %% [markdown]
# We will now look into outliers and remove it, we can easliy look into the mr.describe function we can see
# that there are too many outliers and by using outliers we can see them visually.

# %%
sns.boxplot(mr['last_rech_date_da'])

# %%
plt.boxplot(mr['payback30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x234cd9327f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x234cd932eb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x234cd932490>],
#  'medians': [<matplotlib.lines.Line2D at 0x234cd93c5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x234cd93c8b0>],
#  'means': []}

# %%
plt.boxplot(mr['amnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x234cd988b80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x234cd994280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x234cd988820>],
#  'medians': [<matplotlib.lines.Line2D at 0x234cd994910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x234cd994be0>],
#  'means': []}

# %%
from scipy.stats import zscore
z=np.abs(zscore(mr))
mo=mr[(z<3)]
mo
# Out:
# C:\Users\ssdev\anaconda3\lib\site-packages\scipy\stats\stats.py:2500: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# <ipython-input-32-4a069c316a52>:3: RuntimeWarning: invalid value encountered in less
#   mo=mr[(z<3)]
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0      3055.050       3065.15    220.13    260.13
# 0           0   40191   272.0      3055.050       3065.15    220.13    260.13
# 0           0   40191   272.0      3055.050       3065.15    220.13    260.13
# 0           0   40191   272.0      3055.050       3065.15    220.13    260.13
# 0           0   40191   272.0      3055.050       3065.15    220.13    260.13
# ...       ...     ...     ...           ...           ...       ...       ...
# 209592      1  121263  1581.0      4489.362       4534.82    483.92    631.20
# 209592      1  121263  1581.0      4489.362       4534.82    483.92    631.20
# ...

# %% [markdown]
# We try to check that the target column has how many data potins and are they distributed evenly or not.

# %%
pd.value_counts(mr['label'])
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
ab=pd.value_counts(mr['label'])
ab.plot(kind='bar')
